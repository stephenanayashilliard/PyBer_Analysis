# %% [markdown]
# # Matplotlib Practice

# %%
# Import Matplotlib
import matplotlib

# %% [markdown]
# # Pyplot provides a MATLAB-like interface for making plots.

# %%
# Import dependences
import matplotlib.pyplot as plt

# %%
# Add magic command
# Using % with inline value displays the chart within the cell for a jupyter Notebook File
# %matplotlib inline

# %% [markdown]
# # Create a Line Chart Using the MATLAB Method

# %%
# Set the x-axis to a list of strings for each month.
x_axis =  ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %% [markdown]
# # Create a Line Chart Using the Object-Oriented Interface

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
# The plt.subplots() function returns a tuple that contains a figure and axes object(s).
# fig, ax = plt.subplots() unpacks the tuple into the variables fig and ax.
# The first variable, fig, references the figure.
# The second variable, ax, references the axes of the figure and allows us to annotate the figure.
# The ax.plot(x_axis, y_axis) plots the data from the x and y axes.

fig = plt.figure()             
ax = fig.add_subplot() 
ax.plot(x_axis, y_axis)

# %%
# Create the plot
plt.plot(x_axis, y_axis)
plt.show()

# %%
# The fig, ax = plt.subplots() line of code can also be written like this.
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %% [markdown]
# # To change figure-level attributes (such as axis labels, a title, or a legend) or save the figure as an image, use fig = plt.figure().

# %% [markdown]
# # plt.show()
# # This function looks for all the active figure objects and opens a window that displays them if you have two or more sets of data to plot.
# # Should only be used once per session because it can cause the graph to display improperly. If you have problems with data not being displayed properly, you may have to restart your kernel and clear your output.

# %%
# Create the plot.
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %% [markdown]
# # Annotate Charts Using the MATLAB Method

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, marker="*", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %% [markdown]
# # Annotate Charts Using the Object-Oriented Interface

# %%
# Adding Line Color, Modified line width and markers

fig = plt.figure()
ax = fig.add_subplot()
ax.set_title("PyBer Fare by month")
ax.set_xlabel("Date")
ax.set_ylabel("Fare ($)")
ax.grid()
ax.set_ylim(0,45)
ax.plot(x_axis, y_axis, marker="D", linewidth=2, color='g', label="Boston")
ax.legend()

# %% [markdown]
# # Create Bar Charts Using the MATLAB Approach

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis,y_axis, color="green", label="Boston")
# Create labels for x and y.
plt.xlabel("Date")
plt.ylabel("Fare ($)")
plt.ylim(0,45)
# Create a title
plt.title("Pyber Fare by Month")
# Add a legend
plt.legend()

# %% [markdown]
# # Create a Horizontal Bar Chart

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot on opposite axis
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Inverting the the y-axis
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %% [markdown]
# # Annotate the Bar Chart

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label="Boston")
plt.gca().invert_yaxis()
plt.ylabel("Date")
plt.xlabel("Fare ($)")
plt.title("Pyber Fare by Month")
plt.legend()

# %% [markdown]
# # Create Bar Charts Using the Object-Oriented Approach

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create a Vertical Bar Chart
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a Horizontal Bar Chart
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Data on Opposite Axes
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# # Annotation of the Object Oriented Bar Chart

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color ="cyan")
ax.invert_yaxis()
ax.set_title("PyBer Fare by month")
ax.set_ylabel("Date")
ax.set_xlabel("Fare ($)")
ax.legend("Chicago")

# %% [markdown]
# # Create a Scatter Plot Using the MATLAB Method

# %%
import matplotlib.pyplot as plt

# %%
x = [50,42,39,34,32,48,22,17,8,13]
y = [17,19,21,22,24,23,34,31,43,35]

# %%
plt.scatter (x,y, c='green')
plt.xlabel ("Total Number of Rides (Per City)")
plt.ylabel ("Average Fare ($)")
plt.title ("Average Fare vs Total Rides")
# Out:
# Text(0.5, 1.0, 'Average Fare vs Total Rides')

# %%
#Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# When we use the plt.plot() function to create a scatter plot, 
# we need to add a lowercase "o" as a parameter inside the parentheses. 
# This switches the plot from a line chart to a scatter plot.
plt.plot(x_axis, y_axis, "o")

# %% [markdown]
# # To create a scatter plot using the plt.scatter() function,
# # add the x-axis and y-axis parameters inside the parentheses, as shown here:

# %%
plt.scatter(y_axis, x_axis, color="red", label="Chicago")
plt.xlim(0,50)
plt.ylabel("Date")
plt.xlabel("Fare ($)")
plt.gca().invert_yaxis()
plt.title("Pyber Fare by Month")
plt.legend()

# %% [markdown]
# # Create a Bubble Chart Using the MATLAB Method

# %%
# Create the Scatter Plot
plt.scatter(x_axis, y_axis)

# %%
# Changing Marker Size
# to change the size of our marker on the graph, we have to use the s, or size parameter, for the marker. 
# The s parameter must be equal to a feature of our data. 
# We will make the size of each marker equal to the data floating-point decimal values of the y-axis by using s=y_axis.
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# We can adjust the size by multiplying the data in the y-axis by any value. 
# Let's multiply each data point in the y-axis by 3 and see what happens. 
# To do this, we can iterate through the y-axis data and multiply each data point by 3 and add it to a new list, like this:
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# Using list comprehension technique to replace: for in loop
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %% [markdown]
# # Create a Scatter Plot Using the Object-Oriented Interface

# %%
# Create Scatter Plot
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %% [markdown]
# # Create a Bubble Chart Using the Object-Oriented Interface

# %%
# Create a Bubble Chart
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %% [markdown]
# # Annotating the Bubble Chart

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, c="skyblue", s= [i*5 for i in y_axis], alpha=0.2, edgecolor="black", label="Boston", linewidth=2 )
ax.set_title("PyBer Fare by month")
ax.set_ylabel("Date")
ax.set_xlabel("Fare ($)")
ax.set_xlim(0,50)
ax.invert_yaxis()
ax.legend()

# %% [markdown]
# # Create a Pie Chart Using the MATLAB Method

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
# Let's make this chart more impactful by adding some bling. We have a few options with pie charts: 
# we can add percentages to the wedges, add specific colors, and explode or "pop out" one or more wedges.
# Let's add percentages for each month and "explode" the largest percentage, which is July, the seventh value in the x_axis. 
# The "explode" parameter will offset the indicated wedge by a fraction of the radius, 
# where "0" is zero distance from the center of the pie, and "1" is completely outside the diameter of the pie.
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x242f643d5c8>,
# ...
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
# ...

# %%
# Increase the size of the Piechart
import matplotlib.pyplot as plt
plt.subplots(figsize=(8,8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x242f64c7448>,
# ...
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
# ...

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %% [markdown]
# # Create a Pie Chart Using the Object-Oriented Interface

# %%
fig, ax = plt.subplots(figsize=(8,8),)
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values =(0,0,.10,0,0,0,.10,0,0,0,0,0)
ax.pie(y_axis,labels=x_axis, autopct=("%.1f%%"), explode=explode_values, shadow=True, colors=colors, startangle=90, counterclock=False)
plt.show()
